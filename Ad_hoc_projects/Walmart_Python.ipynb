# %% [markdown]
# <a href="https://colab.research.google.com/github/Santanukolkata/Data_Science/blob/master/Ad_hoc_projects/Walmart_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Retail/Walmart_Store_sales.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  ...  Fuel_Price         CPI  Unemployment
# 0      1  05-02-2010    1643690.90  ...       2.572  211.096358         8.106
# 1      1  12-02-2010    1641957.44  ...       2.548  211.242170         8.106
# 2      1  19-02-2010    1611968.17  ...       2.514  211.289143         8.106
# 3      1  26-02-2010    1409727.59  ...       2.561  211.319643         8.106
# 4      1  05-03-2010    1554806.68  ...       2.625  211.350143         8.106
#
# [5 rows x 8 columns]

# %%
#checking the columns
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
#checking column info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
# Store           6435 non-null int64
# Date            6435 non-null object
# Weekly_Sales    6435 non-null float64
# Holiday_Flag    6435 non-null int64
# Temperature     6435 non-null float64
# Fuel_Price      6435 non-null float64
# CPI             6435 non-null float64
# Unemployment    6435 non-null float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
#checking the null value of any columns
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
#changing date columns
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
# Store           6435 non-null int64
# Date            6435 non-null datetime64[ns]
# Weekly_Sales    6435 non-null float64
# Holiday_Flag    6435 non-null int64
# Temperature     6435 non-null float64
# Fuel_Price      6435 non-null float64
# CPI             6435 non-null float64
# Unemployment    6435 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %% [markdown]
# # Basic Statistics tasks

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %% [markdown]
# # Which store has maximum sales

# %%
store_wise_sales = df.groupby(['Store'])['Weekly_Sales'].sum()

# %%
store_wise_sales.sort_values().head(1)
# Out:
# Store
# 33    37160221.96
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# # Which store has maximum standard deviation i.e., the sales vary a lot. Also, find out the coefficient of mean to standard deviation

# %%
df.std()
# Out:
# Store               12.988182
# Weekly_Sales    564366.622054
# Holiday_Flag         0.255049
# Temperature         18.444933
# Fuel_Price           0.459020
# CPI                 39.356712
# Unemployment         1.875885
# dtype: float64

# %%
store_wise_mean = df.groupby(['Store'])['Weekly_Sales'].mean()

# %%
store_wise_mean
# Out:
# Store
# 1     1.555264e+06
# 2     1.925751e+06
# 3     4.027044e+05
# 4     2.094713e+06
# 5     3.180118e+05
# 6     1.564728e+06
# 7     5.706173e+05
# 8     9.087495e+05
# 9     5.439806e+05
# 10    1.899425e+06
# 11    1.356383e+06
# 12    1.009002e+06
# 13    2.003620e+06
# 14    2.020978e+06
# 15    6.233125e+05
# 16    5.192477e+05
# 17    8.935814e+05
# 18    1.084718e+06
# 19    1.444999e+06
# 20    2.107677e+06
# 21    7.560691e+05
# 22    1.028501e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 25    7.067215e+05
# 26    1.002912e+06
# 27    1.775216e+06
# 28    1.323522e+06
# 29    5.394514e+05
# 30    4.385796e+05
# 31    1.395901e+06
# 32    1.166568e+06
# 33    2.598617e+05
# 34    9.667816e+05
# 35    9.197250e+05
# 36    3.735120e+05
# 37    5.189003e+05
# 38    3.857317e+05
# 39    1.450668e+06
# 40    9.641280e+05
# 41    1.268125e+06
# 42    5.564039e+05
# 43    6.333247e+05
# 44    3.027489e+05
# 45    7.859814e+05
# Name: Weekly_Sales, dtype: float64

# %%
store_wise_std = df.groupby(['Store'])['Weekly_Sales'].std()

# %%
store_wise_std
# Out:
# Store
# 1     155980.767761
# 2     237683.694682
# 3      46319.631557
# 4     266201.442297
# 5      37737.965745
# 6     212525.855862
# 7     112585.469220
# 8     106280.829881
# 9      69028.666585
# 10    302262.062504
# 11    165833.887863
# 12    139166.871880
# 13    265506.995776
# 14    317569.949476
# 15    120538.652043
# 16     85769.680133
# 17    112162.936087
# 18    176641.510839
# 19    191722.638730
# 20    275900.562742
# 21    128752.812853
# 22    161251.350631
# 23    249788.038068
# 24    167745.677567
# 25    112976.788600
# 26    110431.288141
# 27    239930.135688
# 28    181758.967539
# 29     99120.136596
# 30     22809.665590
# 31    125855.942933
# 32    138017.252087
# 33     24132.927322
# 34    104630.164676
# 35    211243.457791
# 36     60725.173579
# 37     21837.461190
# 38     42768.169450
# 39    217466.454833
# 40    119002.112858
# 41    187907.162766
# 42     50262.925530
# 43     40598.413260
# 44     24762.832015
# 45    130168.526635
# ...

# %%
pd.concat([store_wise_mean,store_wise_std],axis=1)
# Out:
#        Weekly_Sales   Weekly_Sales
# Store
# 1      1.555264e+06  155980.767761
# 2      1.925751e+06  237683.694682
# 3      4.027044e+05   46319.631557
# 4      2.094713e+06  266201.442297
# 5      3.180118e+05   37737.965745
# 6      1.564728e+06  212525.855862
# 7      5.706173e+05  112585.469220
# 8      9.087495e+05  106280.829881
# 9      5.439806e+05   69028.666585
# 10     1.899425e+06  302262.062504
# 11     1.356383e+06  165833.887863
# 12     1.009002e+06  139166.871880
# 13     2.003620e+06  265506.995776
# 14     2.020978e+06  317569.949476
# 15     6.233125e+05  120538.652043
# 16     5.192477e+05   85769.680133
# 17     8.935814e+05  112162.936087
# 18     1.084718e+06  176641.510839
# 19     1.444999e+06  191722.638730
# 20     2.107677e+06  275900.562742
# 21     7.560691e+05  128752.812853
# 22     1.028501e+06  161251.350631
# 23     1.389864e+06  249788.038068
# 24     1.356755e+06  167745.677567
# 25     7.067215e+05  112976.788600
# ...

# %%
df['quarter'] = df['Date'].dt.quarter
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# 5         1 2010-12-03    1439541.59             0        57.79       2.667
# 6         1 2010-03-19    1472515.79             0        54.58       2.720
# 7         1 2010-03-26    1404429.92             0        51.45       2.732
# 8         1 2010-02-04    1594968.28             0        62.27       2.719
# 9         1 2010-09-04    1545418.53             0        65.86       2.770
# 10        1 2010-04-16    1466058.28             0        66.32       2.808
# ...

# %%
import datetime

date_time_str = '2018-06-29 08:15:27.243860'
date_time_obj = datetime.datetime.strptime(date_time_str, '%Y-%m-%d %H:%M:%S.%f')

# %%
start_date = datetime.datetime(2012, 7, 1)
end_date = datetime.datetime(2012, 9, 30)

# %%
filter_q3 = (df['Date'] > start_date) & (df['Date'] <= end_date)

# %%
df_filtered_q3 = df.loc[filter_q3]

# %%
df_q3_grouped = df_filtered_q3.groupby(['Store'])['Weekly_Sales'].sum()

# %%
min = df_filtered_q3.groupby(['Store'])['Weekly_Sales'].sum().min()
max = df_filtered_q3.groupby(['Store'])['Weekly_Sales'].sum().max()

# %%
start_date_1 = datetime.datetime(2012, 4, 1)
end_date_1 = datetime.datetime(2012, 6, 30)

# %%
filter_q2 = (df['Date'] > start_date_1) & (df['Date'] <= end_date_1)

# %%
df_filtered_q2 = df.loc[filter_q2]
df_filtered_q2
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 100       1 2012-06-01    1550369.92             0        49.01       3.157
# 113       1 2012-06-04    1899676.88             0        70.43       3.891
# 114       1 2012-04-13    1621031.70             0        69.07       3.891
# 115       1 2012-04-20    1521577.87             0        66.76       3.877
# 116       1 2012-04-27    1468928.37             0        67.23       3.814
# 117       1 2012-04-05    1684519.99             0        75.55       3.749
# 119       1 2012-05-18    1595901.87             0        70.33       3.630
# 120       1 2012-05-25    1555444.55             0        77.22       3.561
# 123       1 2012-06-15    1630607.00             0        79.35       3.393
# 124       1 2012-06-22    1527845.81             0        78.39       3.346
# 125       1 2012-06-29    1540421.49             0        84.88       3.286
# ...

# %%
df_q2_grouped = df_filtered_q2.groupby(['Store'])['Weekly_Sales'].sum()
df_q2_grouped
# Out:
# Store
# 1     21036965.58
# 2     25085123.61
# 3      5562668.16
# 4     28384185.16
# 5      4427262.21
# 6     20728970.16
# 7      7613593.92
# 8     11934275.61
# 9      7431320.13
# 10    23598433.93
# 11    17879095.77
# 12    13193365.04
# 13    26803225.55
# 14    24427769.06
# 15     7867952.23
# 16     6626133.44
# 17    12918892.02
# 18    13834706.08
# 19    18315278.56
# 20    27550180.62
# 21     9226279.62
# 22    13329065.39
# 23    18283424.90
# 24    17768191.98
# 25     9247467.19
# 26    13218289.66
# 27    22593640.73
# 28    16985999.95
# 29     7034493.19
# 30     5786335.45
# 31    18249155.35
# 32    15415236.21
# 33     3512138.05
# 34    12858027.98
# 35    10753570.97
# 36     4090378.90
# 37     6859777.96
# 38     5732362.70
# 39    20191585.63
# 40    12849747.45
# 41    17560035.88
# 42     7608247.31
# 43     8239792.67
# 44     4322555.33
# 45    10278900.05
# Name: Weekly_Sales, dtype: float64

# %%
df_conc = pd.concat([df_q2_grouped,df_q3_grouped],axis=1)
df_conc
df_conc.columns = ['Sales_q2','Sales_q3']
df_conc
# Out:
#           Sales_q2     Sales_q3
# Store
# 1      21036965.58  18633209.98
# 2      25085123.61  22396867.61
# 3       5562668.16   4966495.93
# 4      28384185.16  25652119.35
# 5       4427262.21   3880621.88
# 6      20728970.16  18341221.11
# 7       7613593.92   7322393.92
# 8      11934275.61  10873860.34
# 9       7431320.13   6528239.56
# 10     23598433.93  21169356.45
# 11     17879095.77  16094363.07
# 12     13193365.04  11777508.50
# 13     26803225.55  24319994.35
# 14     24427769.06  20140430.40
# 15      7867952.23   6909374.37
# 16      6626133.44   6441311.11
# 17     12918892.02  11533998.38
# 18     13834706.08  12507521.72
# 19     18315278.56  16644341.31
# 20     27550180.62  24665938.11
# 21      9226279.62   8403507.99
# 22     13329065.39  11818544.33
# 23     18283424.90  17103654.36
# 24     17768191.98  16125999.86
# 25      9247467.19   8309440.44
# 26     13218289.66  12417575.35
# 27     22593640.73  20191238.11
# 28     16985999.95  15055659.67
# ...

# %%
df_conc.pct_change(axis='columns').sort_values(by='Sales_q3', ascending=False)
# Out:
#        Sales_q2  Sales_q3
# Store
# 16          NaN -0.027893
# 7           NaN -0.038247
# 35          NaN -0.046631
# 26          NaN -0.060576
# 39          NaN -0.063969
# 23          NaN -0.064527
# 41          NaN -0.067565
# 44          NaN -0.069882
# 32          NaN -0.082585
# 37          NaN -0.088815
# 8           NaN -0.088855
# 21          NaN -0.089177
# 19          NaN -0.091232
# 24          NaN -0.092423
# 13          NaN -0.092647
# 40          NaN -0.093549
# 33          NaN -0.095402
# 18          NaN -0.095932
# 4           NaN -0.096253
# 31          NaN -0.098351
# 11          NaN -0.099822
# 25          NaN -0.101436
# 42          NaN -0.102180
# 10          NaN -0.102934
# 30          NaN -0.104446
# 20          NaN -0.104691
# 43          NaN -0.104744
# 38          NaN -0.105204
# 27          NaN -0.106331
# 2           NaN -0.107165
# 3           NaN -0.107174
# 17          NaN -0.107199
# 12          NaN -0.107316
# 34          NaN -0.107464
# ...

# %%
df_non_holiday = df[df.Holiday_Flag== 0]
df_holiday = df[df.Holiday_Flag == 1]
mean_non_holiday = df_non_holiday['Weekly_Sales'].mean()

# %%
df_holiday_high_sales = df_holiday[df_holiday.Weekly_Sales > mean_non_holiday]
df_holiday_high_sales.sort_values(by = 'Weekly_Sales',ascending=False)
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 523       4 2011-11-25    3004702.33             1        47.96       3.225
# 1381     10 2011-11-25    2950198.64             1        60.68       3.760
# 1329     10 2010-11-26    2939946.38             1        55.33       3.162
# 1901     14 2010-11-26    2921709.71             1        46.15       3.039
# 2811     20 2011-11-25    2906233.25             1        46.38       3.492
# 1810     13 2011-11-25    2864170.61             1        38.89       3.445
# 2759     20 2010-11-26    2811634.04             1        46.66       3.039
# 471       4 2010-11-26    2789469.45             1        48.08       2.752
# 1758     13 2010-11-26    2766400.05             1        28.22       2.830
# 1953     14 2011-11-25    2685351.81             1        48.71       3.492
# 185       2 2010-11-26    2658725.29             1        62.98       2.735
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
df_g = df.groupby(['Store'],as_index=False)
df_g = df_g.aggregate(np.sum)
df_g
# Out:
#     Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price           CPI  \
# 0       1  2.224028e+08            10      9767.87     460.417  30887.555523
# 1       2  2.753824e+08            10      9754.94     460.417  30837.422420
# 2       3  5.758674e+07            10     10215.09     460.417  31372.988971
# 3       4  2.995440e+08            10      8902.23     460.027  18401.192733
# 4       5  4.547569e+07            10      9925.65     460.417  30968.878137
# 5       6  2.237561e+08            10      9967.10     460.417  31110.107182
# 6       7  8.159828e+07            10      5680.00     463.543  27693.986741
# 7       8  1.299512e+08            10      8939.50     460.417  31379.780750
# 8       9  7.778922e+07            10      9691.85     460.417  31406.616557
# 9      10  2.716177e+08            10     10330.49     511.357  18401.192733
# 10     11  1.939628e+08            10     10364.75     460.417  31372.988971
# ...

# %%
x = df_g.loc[:,['CPI','Fuel_Price','Unemployment']]
y = df_g.loc[:,['Weekly_Sales']]

# %%
reg = lm.fit(x,y)

# %%
reg.coef_
# Out:
# array([[  -588.74451679, 456524.85146824, -56408.90333887]])

# %%
reg.intercept_
# Out:
# array([9426069.04883459])
