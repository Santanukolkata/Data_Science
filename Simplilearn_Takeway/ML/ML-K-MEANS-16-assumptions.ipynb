# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(12, 12))

# %% [markdown]
# ### make_blobs
#
# __n_samples__ : int or array-like, optional (default=100)
# If int, it is the total number of points equally divided among clusters. If array-like, each element of the sequence indicates the number of samples per cluster.
#
# __n_features__ : int, optional (default=2)
# The number of features for each sample.
#
# __centers__ : (default=None) The number of centers to generate, or the fixed center locations. If n_samples is an int and centers is None, 3 centers are generated.
#
# __cluster_std__ : float or sequence of floats, optional (default=1.0)
# The standard deviation of the clusters.

# %%
n_samples    = 1500
random_state = 170

X, y = make_blobs(n_samples=n_samples, random_state=random_state)

# %%
X.shape
# Out:
# (1500, 2)

# %%
np.unique(y)
# Out:
# array([0, 1, 2])

# %%
# Incorrect number of clusters
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X)

#plt.subplot(221)
plt.scatter(X[:, 0], 
            X[:, 1], 
            c=y_pred)

plt.title("correct Number of Blobs")
# Out:
# Text(0.5, 1.0, 'correct Number of Blobs')

# %%
X[:3]
# Out:
# array([[ -5.19811282,   0.64186932],
#        [ -5.75229538,   0.41862711],
#        [-10.84489837,  -7.55352273]])

# %%
transformation = [[0.60834549, -0.63667341], 
                  [-0.40887718, 0.85253229]]

# %%
# distributed data
X_aniso        = np.dot(X, transformation)

y_pred  = KMeans(n_clusters=3, 
                 random_state=random_state).fit_predict(X_aniso)

#plt.subplot(222)
plt.scatter(X_aniso[:, 0], 
            X_aniso[:, 1], 
            c=y_pred)

plt.title("Anisotropicly Distributed Blobs")
# Out:
# Text(0.5, 1.0, 'Anisotropicly Distributed Blobs')
