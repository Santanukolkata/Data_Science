# %% [markdown]
# <a href="https://colab.research.google.com/github/Santanukolkata/Data_Science/blob/master/Models/Preprocessing/Wrapper_SFS_wine_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
df_wine =pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv",sep=';')
df_wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70          0.0  ...       0.56      9.4        5
# 1            7.8              0.88          0.0  ...       0.68      9.8        5
#
# [2 rows x 12 columns]

# %%
X=df_wine.drop(columns="quality")
Y=df_wine["quality"]
Y_bin=df_wine["quality"].apply(lambda x:1 if x >7 else 0 )
Y_bin.head(2)
# Out:
# 0    0
# 1    0
# Name: quality, dtype: int64

# %%
import statsmodels.api as sm
def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(list(initial_features))>0):
        remaining_features = list(set(initial_features)-set(best_features))
        print(remaining_features)
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.Logit(target, data[best_features+[new_column]]).fit()
            new_pval[new_column] = model.pvalues[new_column]
        print(new_pval)
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
            print('best_features',best_features)
        else:
            break
    return best_features

print(forward_selection(X,Y_bin,0.3))
# Out:
# ['chlorides', 'volatile acidity', 'free sulfur dioxide', 'sulphates', 'alcohol', 'density', 'total sulfur dioxide', 'fixed acidity', 'pH', 'citric acid', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.059044
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.063758
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.096286
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.075455
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.070783
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.061624
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.088837
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.067458
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.061272
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.214992
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.074113
#          Iterations 9
# chlorides               2.809482e-68
# volatile acidity        8.163082e-63
# free sulfur dioxide     2.016316e-59
# sulphates               3.295406e-83
# alcohol                 5.418356e-85
# density                 1.913898e-79
# total sulfur dioxide    5.969906e-57
# fixed acidity           4.826516e-78
# pH                      9.415461e-79
# citric acid             2.950297e-52
# residual sugar          3.662953e-79
# dtype: float64
# best_features ['alcohol']
# ['chlorides', 'volatile acidity', 'free sulfur dioxide', 'sulphates', 'density', 'total sulfur dioxide', 'fixed acidity', 'pH', 'citric acid', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.058968
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.062522
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.068776
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.070732
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.050679
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.067011
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.067213
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.049699
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.070092
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.069957
#          Iterations 9
# chlorides               2.750428e-09
# volatile acidity        5.341032e-06
# free sulfur dioxide     2.623496e-02
# sulphates               6.972534e-01
# density                 4.886507e-13
# total sulfur dioxide    5.209910e-03
# fixed acidity           9.634249e-04
# pH                      4.166194e-13
# citric acid             1.336934e-01
# residual sugar          1.987324e-01
# dtype: float64
# best_features ['alcohol', 'pH']
# ['chlorides', 'volatile acidity', 'free sulfur dioxide', 'sulphates', 'density', 'total sulfur dioxide', 'fixed acidity', 'citric acid', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.047879
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.049554
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.049475
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.049168
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.048939
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.049069
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.048634
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.049592
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.048914
#          Iterations 10
# chlorides               0.028960
# volatile acidity        0.503395
# free sulfur dioxide     0.415698
# sulphates               0.138683
# density                 0.112085
# total sulfur dioxide    0.224987
# fixed acidity           0.069120
# citric acid             0.557093
# residual sugar          0.148494
# dtype: float64
# best_features ['alcohol', 'pH', 'chlorides']
# ['volatile acidity', 'free sulfur dioxide', 'sulphates', 'density', 'total sulfur dioxide', 'fixed acidity', 'citric acid', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.047869
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.047391
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.046368
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.047827
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.046907
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.047783
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.047779
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.047652
#          Iterations 10
# volatile acidity        0.858691
# free sulfur dioxide     0.234183
# sulphates               0.010040
# density                 0.683669
# total sulfur dioxide    0.137293
# fixed acidity           0.583066
# citric acid             0.573652
# residual sugar          0.430451
# dtype: float64
# best_features ['alcohol', 'pH', 'chlorides', 'sulphates']
# ['volatile acidity', 'free sulfur dioxide', 'density', 'total sulfur dioxide', 'fixed acidity', 'citric acid', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.046367
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.045760
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.046225
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.045055
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.046154
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.046342
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.046148
#          Iterations 10
# volatile acidity        0.960842
# free sulfur dioxide     0.188947
# density                 0.502046
# total sulfur dioxide    0.082401
# fixed acidity           0.412655
# citric acid             0.776098
# residual sugar          0.436472
# dtype: float64
# best_features ['alcohol', 'pH', 'chlorides', 'sulphates', 'total sulfur dioxide']
# ['volatile acidity', 'free sulfur dioxide', 'density', 'fixed acidity', 'citric acid', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.045040
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.045034
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044973
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044479
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.045054
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044936
#          Iterations 11
# volatile acidity       0.826305
# free sulfur dioxide    0.791893
# density                0.610564
# fixed acidity          0.182304
# citric acid            0.954416
# residual sugar         0.555234
# dtype: float64
# best_features ['alcohol', 'pH', 'chlorides', 'sulphates', 'total sulfur dioxide', 'fixed acidity']
# ['volatile acidity', 'free sulfur dioxide', 'density', 'citric acid', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.044476
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044458
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044301
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044045
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044460
#          Iterations 11
# volatile acidity       0.916447
# free sulfur dioxide    0.793225
# density                0.448190
# citric acid            0.239590
# residual sugar         0.806682
# dtype: float64
# best_features ['alcohol', 'pH', 'chlorides', 'sulphates', 'total sulfur dioxide', 'fixed acidity', 'citric acid']
# ['density', 'volatile acidity', 'free sulfur dioxide', 'residual sugar']
# Optimization terminated successfully.
#          Current function value: 0.043917
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.043909
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044026
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044012
#          Iterations 11
# density                0.520331
# volatile acidity       0.502765
# free sulfur dioxide    0.804021
# residual sugar         0.752089
# dtype: float64
# ['alcohol', 'pH', 'chlorides', 'sulphates', 'total sulfur dioxide', 'fixed acidity', 'citric acid']

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LogisticRegression  
# Sequential Forward Selection(sfs)
sfs = SFS(LogisticRegression(),
           k_features=11,
           forward=True,
           floating=False,
           scoring = 'accuracy',
          verbose=2,
           cv = 0)

# %%
sfs.fit(X, Y_bin)
sfs.k_feature_names_
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.1s finished
#
# [2020-03-20 04:45:03] Features: 1/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.1s finished
#
# [2020-03-20 04:45:03] Features: 2/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.1s finished
#
# [2020-03-20 04:45:03] Features: 3/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.1s finished
#
# [2020-03-20 04:45:03] Features: 4/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s finished
#
# [2020-03-20 04:45:03] Features: 5/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s finished
#
# [2020-03-20 04:45:03] Features: 6/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
#
# [2020-03-20 04:45:04] Features: 7/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s finished
#
# [2020-03-20 04:45:04] Features: 8/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
#
# [2020-03-20 04:45:04] Features: 9/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s finished
#
# [2020-03-20 04:45:04] Features: 10/11 -- score: 0.9887429643527205[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
#
# [2020-03-20 04:45:04] Features: 11/11 -- score: 0.9887429643527205
# ('fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol')

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
sfs1 = SFS(clf,
           k_features=11,
           forward=True,
           floating=False,
           verbose=2,
           scoring='accuracy')
sfs1 = sfs1.fit(X, Y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   11.3s finished
#
# [2020-03-20 04:52:09] Features: 1/11 -- score: 0.5209247648902822[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   12.6s finished
#
# [2020-03-20 04:52:22] Features: 2/11 -- score: 0.48656543887147335[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   11.0s finished
#
# [2020-03-20 04:52:33] Features: 3/11 -- score: 0.5196806426332288[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   11.4s finished
#
# [2020-03-20 04:52:44] Features: 4/11 -- score: 0.52594631661442[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    9.9s finished
#
# [2020-03-20 04:52:54] Features: 5/11 -- score: 0.562840909090909[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    8.6s finished
#
# [2020-03-20 04:53:03] Features: 6/11 -- score: 0.5784992163009405[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    7.3s finished
#
# [2020-03-20 04:53:10] Features: 7/11 -- score: 0.5722511755485893[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    5.9s finished
#
# [2020-03-20 04:53:16] Features: 8/11 -- score: 0.5778644200626959[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.2s finished
#
# [2020-03-20 04:53:21] Features: 9/11 -- score: 0.5803702978056426[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s finished
#
# [2020-03-20 04:53:25] Features: 10/11 -- score: 0.5734855015673982[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s finished
#
# [2020-03-20 04:53:26] Features: 11/11 -- score: 0.5634717868338559

# %%
feat_cols = list(sfs1.k_feature_idx_)
print(feat_cols)
df_wine.columns[feat_cols]
