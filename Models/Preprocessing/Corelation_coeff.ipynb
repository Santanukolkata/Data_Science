# %% [markdown]
# <a href="https://colab.research.google.com/github/Santanukolkata/Data_Science/blob/master/Models/Preprocessing/Corelation_coeff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from  sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.stats import kendalltau,pearsonr,spearmanr

# %%
study_hours    = np.array([2,  4, 6, 8, 10])
sleeping_hours = np.array([10, 8, 6, 4,  2])

# %%
np.cov(study_hours, sleeping_hours)
# Out:
# array([[ 10., -10.],
#        [-10.,  10.]])

# %%
np.corrcoef(study_hours, sleeping_hours)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %% [markdown]
# Positive Correlation:

# %%
np.random.seed(2)

# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Positive Correlation with some noise
y = x + np.random.normal(0, 10, 1000)

np.corrcoef(x, y)
# Out:
# array([[1.        , 0.79433333],
#        [0.79433333, 1.        ]])

# %%
plt.scatter(x, y);

# %% [markdown]
# Correlation Matrix

# %%
df = pd.DataFrame({'Col1': np.random.randint(0, 50, 1000)})

# positively correlated with 'col1'
df['Col2'] = df['Col1'] + np.random.normal(0, 10, 1000) 

# negatively correlated with 'col1'
df['Col3'] = 100 - df['Col1'] + np.random.normal(0, 5, 1000) 

# not correlated with 'col1'
df['Col4'] = np.random.randint(0, 50, 1000)

# %%
df.corr()
# Out:
#           Col1      Col2      Col3      Col4
# Col1  1.000000  0.829782 -0.942158 -0.045955
# Col2  0.829782  1.000000 -0.778774 -0.028066
# Col3 -0.942158 -0.778774  1.000000  0.055416
# Col4 -0.045955 -0.028066  0.055416  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(9, 6));

# %%
plt.figure(figsize=(9, 6))

plt.matshow(df.corr())

plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar();

# %%
# Using seaborn heatmap
sns.heatmap(df.corr(), annot=True);

# %%
print(df.corr(method='pearson'))
print(df.corr(method='spearman'))
print(df.corr(method='kendall'))
# Out:
#           Col1      Col2      Col3      Col4
# Col1  1.000000  0.829782 -0.942158 -0.045955
# Col2  0.829782  1.000000 -0.778774 -0.028066
# Col3 -0.942158 -0.778774  1.000000  0.055416
# Col4 -0.045955 -0.028066  0.055416  1.000000
#           Col1      Col2      Col3      Col4
# Col1  1.000000  0.839201 -0.945926 -0.046465
# Col2  0.839201  1.000000 -0.788581 -0.021722
# Col3 -0.945926 -0.788581  1.000000  0.055153
# Col4 -0.046465 -0.021722  0.055153  1.000000
#           Col1      Col2      Col3      Col4
# Col1  1.000000  0.641596 -0.798058 -0.031044
# Col2  0.641596  1.000000 -0.579792 -0.015507
# Col3 -0.798058 -0.579792  1.000000  0.036591
# Col4 -0.031044 -0.015507  0.036591  1.000000

# %%
print (kendalltau(df['Col1'], df['Col2'])[0])
# Out:
# 0.6415956619268067

# %%
print (kendalltau(df['Col1'], df['Col3'])[0])
# Out:
# -0.7980584387181935

# %%
print(pearsonr(df['Col1'], df['Col3']))
# Out:
# (-0.9421584163622871, 0.0)

# %%
print(spearmanr(df['Col1'], df['Col3'])[0])
# Out:
# -0.9459255816397516
